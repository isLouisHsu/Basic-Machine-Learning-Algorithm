# %% [markdown]
# ## HOG

# %%
class HOG():
    
    def __init__(self, cellsize=6, blocksize=2)

# %% [markdown]
# ## LBP

# %% [markdown]
# ## Haar-like

# %% [markdown]
# ## Main

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open('./joker.jpg')
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Reference
# > [图像特征提取三大法宝：HOG特征、LBP特征、Haar-like特征](https://blog.csdn.net/q123456789098/article/details/52748918)
